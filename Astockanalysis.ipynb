# %%
from datetime import date
import nsepy as nsepy11
from nsepy import live
from nsepy import get_history

ticker='TCS' #'SBIN'

dfnse = get_history(symbol=ticker,
                   start=date(2020,12,1),
                   end=date(2022,2,16))

dfnselive = live(symbol=ticker)
# Out:
# Exception in thread Exception in thread Exception in thread Thread-37Thread-42:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
# Thread-39:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
# :
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#                 six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
# six.raise_from(e, None)
# ...

# %%
dfnse.tail(2)

dfnse.columns
dfnse.reset_index(inplace=True)
dfnse.columns

dfnse.head(2)
dfnse.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
dfnse.tail(20)
# Out:
#            Date Symbol Series  Prev Close     Open     High      Low     Last  \
# 267  2021-12-29    TCS     EQ     3706.55  3692.25  3719.95  3685.00  3688.05
# 268  2021-12-30    TCS     EQ     3694.70  3681.35  3740.00  3680.00  3737.00
# 269  2021-12-31    TCS     EQ     3733.75  3742.80  3760.00  3731.30  3740.00
# 270  2022-01-03    TCS     EQ     3738.35  3750.00  3830.00  3745.00  3815.00
# 271  2022-01-04    TCS     EQ     3817.75  3831.10  3889.15  3811.70  3878.70
# 272  2022-01-05    TCS     EQ     3884.75  3865.00  3870.00  3812.40  3856.00
# 273  2022-01-06    TCS     EQ     3860.95  3812.00  3835.00  3772.00  3809.95
# 274  2022-01-07    TCS     EQ     3807.45  3820.00  3864.90  3796.40  3858.90
# 275  2022-01-10    TCS     EQ     3853.50  3978.00  3978.00  3861.00  3884.00
# 276  2022-01-11    TCS     EQ     3879.85  3856.00  3925.00  3856.00  3917.00
# 277  2022-01-12    TCS     EQ     3915.90  3925.00  3929.00  3836.55  3857.00
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=dfnse['Date'],open=dfnse['Open'],high=dfnse['High'],low=dfnse['Low'],close=dfnse['Close'],volume=dfnse['Volume'])])
#fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0b73ddc2645e> in <module>
# ----> 1 fig = go.Figure(data=[go.Candlestick(x=dfnse['Date'],open=dfnse['Open'],high=dfnse['High'],low=dfnse['Low'],close=dfnse['Close'],volume=dfnse['Volume'])])
#       2 #fig.show()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/plotly/graph_objs/_candlestick.py in __init__(self, arg, close, closesrc, customdata, customdatasrc, decreasing, high, highsrc, hoverinfo, hoverinfosrc, hoverlabel, hovertext, hovertextsrc, ids, idssrc, increasing, legendgroup, line, low, lowsrc, meta, metasrc, name, opacity, open, opensrc, selectedpoints, showlegend, stream, text, textsrc, uid, uirevision, visible, whiskerwidth, x, xaxis, xcalendar, xperiod, xperiod0, xperiodalignment, xsrc, yaxis, **kwargs)
#    1696         # Process unknown kwargs
# ...

# %%
go.Figure.write_html(fig,AnalysisOutputChartFileName1,include_plotlyjs='cdn')

# %%
abcd

# %%
# Imports
import pandas as pd
from ipywidgets import widgets as wg
import yfinance as yf
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot

AnalysisOutputChartFileName1="NSEAnalysis1.html"
init_notebook_mode()

tickers = ["FB", "AMZN", "DD", "BRK-A","BHEL.NS"]
tickers1 = ["CUB.NS"]

df = yf.download(
        tickers=tickers1,
        period="1m",
        interval="1d",group_by="column")
        
df.columns

# %%
df.reset_index(inplace=True)
df.columns

# %%
df.head(2)

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])
#fig.show()
go.Figure.write_html(fig,AnalysisOutputChartFileName1,include_plotlyjs='cdn')

# %%
fig = go.Figure()
fig = px.imshow(df,
                labels=dict(y="Depends On Portfolio", x="Requested From Portfolio", color="Dependency Count"),
                   x=dependenciesdf00pvt1.columns,
                y=dependenciesdf00pvt1.index, color_continuous_scale=px.colors.sequential.Sunsetdark, width=1000
               )
#fig.update_xaxes(side="top")

fig.update_layout(
    title_text='Dependencies by Portfolio (Requestor Vs Depends) - Darker Square denotes High value'
)
AnalysisOutputChartFileName1 = "Depend" + AnalysisOutputChartFileName 
go.Figure.write_html(fig,AnalysisOutputChartFileName1,include_plotlyjs='cdn')

# %%
""" icici direct analysis sheet
import pandas as pd
#pip3 install openpyxl # pip3 install xlrd
data = pd.read_excel("marketanalysis.xlsx")
#infate = pd.read_csv("india-inflation-rate-cpi.xls")
data=data.rename(columns={"% Return": "Returns", "Unnamed: 5": "Comments"})
data.shape
data2=data[data['Ratings']=='Buy']
data2.dtypes
data2.Returns.unique() 
data2.CMP.unique()
data2.Target.unique() 
"""
